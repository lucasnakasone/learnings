# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 2 - Blackjack Game
# In this milestone project you will be creating a Complete BlackJack Card Game in Python.
#
# Here are the requirements:
#
# * You need to create a simple text-based [BlackJack](https://en.wikipedia.org/wiki/Blackjack) game
# * The game needs to have one player versus an automated dealer.
# * The player can stand or hit.
# * The player must be able to pick their betting amount.
# * You need to keep track of the player's total money.
# * You need to alert the player of wins, losses, or busts, etc...
#
# And most importantly:
#
# * **You must use OOP and classes in some portion of your game. You can not just use functions in your game. Use classes to help you define the Deck and the Player's hand. There are many right ways to do this, so explore it well!**
#
#
# Feel free to expand this game. Try including multiple players. Try adding in Double-Down and card splits! Remember to you are free to use any resources you want and as always:
#
#
# # HAVE FUN!

# %%
import random
from IPython.display import clear_output
import msvcrt as m

values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8,
          'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':[1, 10]}
suits = ('Hearts', 'Spades', 'Diamonds', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
def wait():
    m.getch()

class Deck:    
    def __init__(self):
        self.cards = []
        for suit in suits:
            for rank in ranks:
                card = Card(rank, suit)
                self.cards.append(card)

    def shuffle(self):
        random.shuffle(self.cards)
        #print("The deck is being shuffled...")
        
    def deal(self):
        return self.cards.pop()
    
    def __str__(self):
        return f'Your deck has {len(self.cards)} cards.'

class Card:
    def __init__(self, rank, suit):
        self.rank = rank
        self.suit = suit
        self.value = values[rank]

class Hand:
    def __init__(self, cards):
        pass

class Dealer:
    points = 0
    pot = 10000.00
    deck = Deck()
    def __init__(self):
        self.hand = []
        #print("Dealer created...")
        #print("Deck created...")
                
    def player_deal(self):
        return self.deck.cards.pop()
    
    def flop(self):
        return [self.deck.cards.pop() for each in range(2)]
    
    def total_points(self):
        for each in self.hand:
            self.points += each.value
    
    def show_cards(self):
        if self.hand == []:
            print("Dealer has no cards")
        else:
            print(">>> Dealer has:")
            print(self.hand[0].rank, 'of', self.hand[0].suit, 'with a value of', self.hand[0].value, 'and another card faced down.')    
    
    def check_points(self):
        pass

    def __str__(self):
        return f"Dealer's has {len(self.deck.cards)} cards in his deck"
    
class Player:
    points = [0, 0]
    pot = 100.00
    def __init__(self):
        self.hand = []
        #print("Player created...")
        
    def show_cards(self):
        if self.hand == []:
            print("You have no cards")
        else:
            print(">>> You have:")
            for each in self.hand:
                print(f"{each.rank} of {each.suit} with a value of {each.value}.")    
    
    def total_points(self):
        #points = [0, 0]
        for each in self.hand:
            if type(each.value) == type([]):
                self.points[0] += each.value[0]
                self.points[1] += each.value[1]
            else:
                self.points[0] += each.value
                self.points[1] += each.value
        if any(isinstance(each, list) for each in self.hand):
            print(f"Totalizing either {self.points[0]} or {self.points[1]} points.")
        else:
            print(f"Totalizing {self.points[0]} points.")
    
    def __str__(self):
        return f"You have a pot of {self.pot} coins."

'''
dealer = Dealer()
player = Player()
bet = 0
dealer.deck.shuffle()
#round = 0
dealer.hand = dealer.flop()
player.hand = dealer.flop()
'''

game_on = True
while True:
            
    clear_output()
    
    print("Welcome to the Black Jack game!")
    print("You're starting with a 100 coins.")
    print("\nThe dealer is shuffling the deck...")
    
    dealer = Dealer()
    player = Player()
    bet = 0
    dealer.deck.shuffle()
    #round = 0
    dealer.hand = dealer.flop()
    player.hand = dealer.flop()
    
    bet = int(input(f"\nHow much will you bet? (Pot: {player.pot}): "))
    player.pot -= bet
    
    '''
    if round > 0:
        print(f"\nBet: {bet}")
        print("\n>>> Dealer has:")
        for each in dealer.hand:
            print(f"{each.rank} of {each.suit} with a value of {each.value}.")
    else:
        bet = int(input(f"\nHow much will you bet? (Pot: {player.pot}): "))
        player.pot -= bet
        dealer.show_cards()
    '''
    
    print("\nDealing...")
    
    dealer.show_cards()
    dealer.total_points()
    player.show_cards()
    player.total_points()
    
    hit_stop = True
    while hit_stop:
        inputs = input("\nWill you (h)it or will you (s)top?: ").upper()
        if inputs == 'H':
            print('Hit!\n')
            player.hand.append(dealer.player_deal())
            player.show_cards()
            player.total_points()
            if player.points[0] > 21 or player.points[1] > 21:
                print("You busted!")
                print(f"You lost all of your bet. Your pot is now: {player.pot}.")
                player.pot -= bet
                #round = 0
                wait()
                hit_stop = False
            #round += 1
            #hit_stop = False
        elif inputs == 'S':
            print('Stop!\n')
            while True:
                dealer.hand.appen(dealer.player_deal())
                if dealer.points > 21:
                    print(f"You won! Dealer busted with {dealer.points}!")
                elif dealer.points > player.points[0] or dealer.points > player.points[1]:
                    print(f"Dealer wins! He wins with {dealer.points} points against {player.points}.")
                elif dealer.points == 21:
                    print(f"Dealer wins with perfect 21 points!")
                    
            #round += 1
            hit_stop = False
        else:
            print("Not a valid choice, think again.")
# Out:
# Welcome to the Black Jack game!
# You're starting with a 100 coins.
#
# The dealer is shuffling the deck...
#
# How much will you bet? (Pot: 100.0): 10
#
# Dealing...
# >>> Dealer has:
# Two of Spades with a value of 2 and another card faced down.
# >>> You have:
# Ace of Diamonds with a value of [1, 10].
# Four of Spades with a value of 4.
# Totalizing 5 points.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Lucas\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-1c15cb667eb8>", line 155, in <module>
#     inputs = input("\nWill you (h)it or will you (s)top?: ").upper()
#   File "C:\Users\Lucas\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 860, in raw_input
#     return self._input_request(str(prompt),
# ...
